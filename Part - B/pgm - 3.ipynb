# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = 'results.csv'
data1 = pd.read_csv(path)

# %%
data1.head()
# Out:
#    Unnamed: 0  Hindi  English  Science  Maths  History  Geograpgy  Total  \
# 0           0     65       10       59      3       71         37    245
# 1           1     94       56        4     67       91         50    362
# 2           2      7       85       76     99       60         25    352
# 3           3     88       46       59     94       52         38    377
# 4           4     39       81       37     38        6         54    255
#
#    Results  Div
# 0        0    3
# 1        1    1
# 2        0    2
# 3        1    1
# 4        1    3

# %%
data = data1.iloc[:, 1: -3]
data.head()
# Out:
#    Hindi  English  Science  Maths  History  Geograpgy
# 0     65       10       59      3       71         37
# 1     94       56        4     67       91         50
# 2      7       85       76     99       60         25
# 3     88       46       59     94       52         38
# 4     39       81       37     38        6         54

# %%
subjects = data.columns[:-1]
subjects
# Out:
# Index(['Hindi', 'English', 'Science', 'Maths', 'History'], dtype='object')

# %%
pass_fail_data = {}
for subject in subjects:
    pass_count = sum(data[subject] >= 35)
    fail_count = sum(data[subject] < 35)
    pass_fail_data[subject] = {'Pass': pass_count, 'Fail': fail_count}
    
pd.DataFrame(pass_fail_counts)
# Out:
#       Overall  Hindi  English  Science  Maths  History
# Pass      598    630      619      600    590      598
# Fail      402    370      381      400    410      402

# %%
sns.scatterplot(x='Science', y='Maths', data=data[:100])
plt.title('Scatter Plot of Science vs Maths')
plt.show()
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
data.mean().plot(kind='line')
plt.title('Line chart')
plt.xlabel('Subjects')
plt.ylabel('Pass/Fail')
plt.show()

# %%
pass_fail_df = pd.DataFrame(pass_fail_data).transpose()
pass_fail_df.plot(kind='bar', stacked='true')
plt.title('Bar chart')
plt.xlabel('Subjects')
plt.ylabel('Pass/Fail')
plt.show()

# %%
plt.hist(data1['Total'], edgecolor='black')
plt.title('Histogram of Total Marks')
plt.xlabel('Total Marks')
plt.ylabel('Frequency')
plt.show()
